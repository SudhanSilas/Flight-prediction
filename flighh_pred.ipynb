# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("flight.xls")

# %%
df
# Out:
#         Airline_ Date of Journey Source Destination no_of_stops Duration  \
# 0      Spice Jet          24 oct    MAA         DEL     NonStop  02h 50m
# 1     Indigo Air          24 oct    MAA         DEL     NonStop  03h 10m
# 2      Spice Jet          24 oct    MAA         DEL       1Stop  05h 30m
# 3       Air Asia          24 oct    MAA         DEL       1Stop  15h 25m
# 4        Vistara          24 oct    MAA         DEL     NonStop  02h 50m
# ...          ...             ...    ...         ...         ...      ...
# 1822    Air Asia           7 dec    MAA         DEL       1Stop  17h 50m
# 1823  Indigo Air           7 dec    MAA         DEL     NonStop  03h 00m
# 1824     Vistara           7 dec    MAA         DEL       2Stop  10h 05m
# 1825   Air India           7 dec    MAA         DEL       1Stop  08h 50m
# 1826   Air India           7 dec    MAA         DEL       1Stop  29h 10m
#
#      Departuretime Arrivaltime  Price
# 0            20:00       22:50   5858
# ...

# %%
df.dtypes
# Out:
# Airline_           object
# Date of Journey    object
# Source             object
# Destination        object
# no_of_stops        object
# Duration           object
# Departuretime      object
# Arrivaltime        object
# Price               int64
# dtype: object

# %%
pd.set_option("display.max_columns", None)

# %%
df.shape
# Out:
# (1827, 9)

# %%
df.dtypes
# Out:
# Airline_           object
# Date of Journey    object
# Source             object
# Destination        object
# no_of_stops        object
# Duration           object
# Departuretime      object
# Arrivaltime        object
# Price               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Airline_', 'Date of Journey', 'Source', 'Destination', 'no_of_stops',
#        'Duration', 'Departuretime', 'Arrivaltime', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Airline_           0
# Date of Journey    0
# Source             0
# Destination        0
# no_of_stops        0
# Duration           0
# Departuretime      0
# Arrivaltime        0
# Price              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline_         1827 non-null   object
#  1   Date of Journey  1827 non-null   object
#  2   Source           1827 non-null   object
#  3   Destination      1827 non-null   object
#  4   no_of_stops      1827 non-null   object
#  5   Duration         1827 non-null   object
#  6   Departuretime    1827 non-null   object
#  7   Arrivaltime      1827 non-null   object
#  8   Price            1827 non-null   int64
# dtypes: int64(1), object(8)
# memory usage: 128.6+ KB

# %%
for i in df.columns:
        print(str(i))
        print(df[i].value_counts())
        print("\n")
# Out:
# Airline_
# Vistara       592
# Indigo Air    471
# Air India     282
# Spice Jet     185
# Air Asia      172
# Go Air        125
# Name: Airline_, dtype: int64
#
#
# Date of Journey
# 9 nov     288
# 11 nov    160
# 7 dec     160
# 17 nov    154
# 3 nov     151
# 7 nov     150
# 26 nov    148
# 5 nov     145
# 29 oct    130
# 27 oct    120
# 26 oct    114
# 25 oct     77
# 24 oct     30
# Name: Date of Journey, dtype: int64
#
#
# Source
# MAA    1827
# Name: Source, dtype: int64
#
#
# Destination
# DEL    1827
# Name: Destination, dtype: int64
#
#
# no_of_stops
# 1Stop      1287
# 2Stop       333
# NonStop     207
# Name: no_of_stops, dtype: int64
#
#
# Duration
# 02h 45m    78
# 02h 50m    77
# 07h 10m    37
# 07h 05m    36
# 07h 40m    34
#            ..
# 28h 50m     1
# 25h 45m     1
# 39h 40m     1
# 13h 55m     1
# 38h 20m     1
# Name: Duration, Length: 241, dtype: int64
#
#
# Departuretime
# 07:00    156
# 09:45     98
# 21:10     96
# 12:30     84
# 06:20     77
# ...

# %%
df.dtypes
# Out:
# Airline_           object
# Date of Journey    object
# Source             object
# Destination        object
# no_of_stops        object
# Duration           object
# Departuretime      object
# Arrivaltime        object
# Price               int64
# dtype: object

# %%
df.head()
# Out:
#      Airline_ Date of Journey Source Destination no_of_stops Duration  \
# 0   Spice Jet          24 oct    MAA         DEL     NonStop  02h 50m
# 1  Indigo Air          24 oct    MAA         DEL     NonStop  03h 10m
# 2   Spice Jet          24 oct    MAA         DEL       1Stop  05h 30m
# 3    Air Asia          24 oct    MAA         DEL       1Stop  15h 25m
# 4     Vistara          24 oct    MAA         DEL     NonStop  02h 50m
#
#   Departuretime Arrivaltime  Price
# 0         20:00       22:50   5858
# 1         21:50       01:00   5937
# 2         19:50       01:20   6290
# 3         22:40       14:05   6853
# 4         21:05       23:55   7286

# %%
new = df["Date of Journey"].str.split(" ", n = 1, expand = True)

# %%
new
# Out:
#        0    1
# 0     24  oct
# 1     24  oct
# 2     24  oct
# 3     24  oct
# 4     24  oct
# ...   ..  ...
# 1822   7  dec
# 1823   7  dec
# 1824   7  dec
# 1825   7  dec
# 1826   7  dec
#
# [1827 rows x 2 columns]

# %%
df["date"]=new[0]
df["month"]=new[1]

# %%
df
# Out:
#         Airline_ Date of Journey Source Destination no_of_stops Duration  \
# 0      Spice Jet          24 oct    MAA         DEL     NonStop  02h 50m
# 1     Indigo Air          24 oct    MAA         DEL     NonStop  03h 10m
# 2      Spice Jet          24 oct    MAA         DEL       1Stop  05h 30m
# 3       Air Asia          24 oct    MAA         DEL       1Stop  15h 25m
# 4        Vistara          24 oct    MAA         DEL     NonStop  02h 50m
# ...          ...             ...    ...         ...         ...      ...
# 1822    Air Asia           7 dec    MAA         DEL       1Stop  17h 50m
# 1823  Indigo Air           7 dec    MAA         DEL     NonStop  03h 00m
# 1824     Vistara           7 dec    MAA         DEL       2Stop  10h 05m
# 1825   Air India           7 dec    MAA         DEL       1Stop  08h 50m
# 1826   Air India           7 dec    MAA         DEL       1Stop  29h 10m
#
#      Departuretime Arrivaltime  Price date month
# ...

# %%
df.drop(["Date of Journey"],axis=1,inplace=True)

# %%
df.head()
# Out:
#      Airline_ Source Destination no_of_stops Duration Departuretime  \
# 0   Spice Jet    MAA         DEL     NonStop  02h 50m         20:00
# 1  Indigo Air    MAA         DEL     NonStop  03h 10m         21:50
# 2   Spice Jet    MAA         DEL       1Stop  05h 30m         19:50
# 3    Air Asia    MAA         DEL       1Stop  15h 25m         22:40
# 4     Vistara    MAA         DEL     NonStop  02h 50m         21:05
#
#   Arrivaltime  Price date month
# 0       22:50   5858   24   oct
# 1       01:00   5937   24   oct
# 2       01:20   6290   24   oct
# 3       14:05   6853   24   oct
# 4       23:55   7286   24   oct

# %%
Duration = list(df["Duration"])

for i in range(len(Duration)):
    if len(Duration[i].split()) != 2:   
        if "h" in duration[i]:
            Duration[i] = Duration[i].strip() + " 0m"  
        else:
            Duration[i] = "0h " + Duration[i]

# %%
duration_hours = []
duration_mins = []
for i in range(len(Duration)):
    duration_hours.append(int(Duration[i].split(sep = "h")[0]))   
    duration_mins.append(int(Duration[i].split(sep = "m")[0].split()[-1]))

# %%
df["Duration_hours"]=duration_hours
df["Duration_mins"]=duration_mins

# %%
df
# Out:
#         Airline_ Source Destination no_of_stops Duration Departuretime  \
# 0      Spice Jet    MAA         DEL     NonStop  02h 50m         20:00
# 1     Indigo Air    MAA         DEL     NonStop  03h 10m         21:50
# 2      Spice Jet    MAA         DEL       1Stop  05h 30m         19:50
# 3       Air Asia    MAA         DEL       1Stop  15h 25m         22:40
# 4        Vistara    MAA         DEL     NonStop  02h 50m         21:05
# ...          ...    ...         ...         ...      ...           ...
# 1822    Air Asia    MAA         DEL       1Stop  17h 50m         18:00
# 1823  Indigo Air    MAA         DEL     NonStop  03h 00m         12:45
# 1824     Vistara    MAA         DEL       2Stop  10h 05m         07:00
# 1825   Air India    MAA         DEL       1Stop  08h 50m         05:55
# 1826   Air India    MAA         DEL       1Stop  29h 10m         09:35
#
#      Arrivaltime  Price date month  Duration_hours  Duration_mins
# ...

# %%
df.drop(["Duration"],axis=1,inplace=True)

# %%
df.head()
# Out:
#      Airline_ Source Destination no_of_stops Departuretime Arrivaltime  Price  \
# 0   Spice Jet    MAA         DEL     NonStop         20:00       22:50   5858
# 1  Indigo Air    MAA         DEL     NonStop         21:50       01:00   5937
# 2   Spice Jet    MAA         DEL       1Stop         19:50       01:20   6290
# 3    Air Asia    MAA         DEL       1Stop         22:40       14:05   6853
# 4     Vistara    MAA         DEL     NonStop         21:05       23:55   7286
#
#   date month  Duration_hours  Duration_mins
# 0   24   oct               2             50
# 1   24   oct               3             10
# 2   24   oct               5             30
# 3   24   oct              15             25
# 4   24   oct               2             50

# %%
new = df["Departuretime"].str.split(":", n = 1, expand = True)

# %%
df["Departure hour"]=new[0]
df["Departure min"]=new[1]

# %%
df.drop(["Departuretime"],axis=1,inplace=True)

# %%
new = df["Arrivaltime"].str.split(":", n = 1, expand = True)

# %%
new.head()
# Out:
#     0   1
# 0  22  50
# 1  01  00
# 2  01  20
# 3  14  05
# 4  23  55

# %%
df["Arrival hour"]=new[0]
df["Arrival min"]=new[1]

# %%
df.head()
# Out:
#      Airline_ Source Destination no_of_stops Arrivaltime  Price date month  \
# 0   Spice Jet    MAA         DEL     NonStop       22:50   5858   24   oct
# 1  Indigo Air    MAA         DEL     NonStop       01:00   5937   24   oct
# 2   Spice Jet    MAA         DEL       1Stop       01:20   6290   24   oct
# 3    Air Asia    MAA         DEL       1Stop       14:05   6853   24   oct
# 4     Vistara    MAA         DEL     NonStop       23:55   7286   24   oct
#
#    Duration_hours  Duration_mins Departure hour Departure min Arrival hour  \
# 0               2             50             20            00           22
# 1               3             10             21            50           01
# 2               5             30             19            50           01
# 3              15             25             22            40           14
# 4               2             50             21            05           23
#
#   Arrival min
# 0          50
# 1          00
# 2          20
# ...

# %%
df.drop(["Arrivaltime"],axis=1,inplace=True)

# %%
df.head()
# Out:
#      Airline_ Source Destination no_of_stops  Price date month  \
# 0   Spice Jet    MAA         DEL     NonStop   5858   24   oct
# 1  Indigo Air    MAA         DEL     NonStop   5937   24   oct
# 2   Spice Jet    MAA         DEL       1Stop   6290   24   oct
# 3    Air Asia    MAA         DEL       1Stop   6853   24   oct
# 4     Vistara    MAA         DEL     NonStop   7286   24   oct
#
#    Duration_hours  Duration_mins Departure hour Departure min Arrival hour  \
# 0               2             50             20            00           22
# 1               3             10             21            50           01
# 2               5             30             19            50           01
# 3              15             25             22            40           14
# 4               2             50             21            05           23
#
#   Arrival min
# 0          50
# 1          00
# 2          20
# 3          05
# 4          55

# %%
df.dtypes
# Out:
# Airline_          object
# Source            object
# Destination       object
# no_of_stops       object
# Price              int64
# date              object
# month             object
# Duration_hours     int64
# Duration_mins      int64
# Departure hour    object
# Departure min     object
# Arrival hour      object
# Arrival min       object
# dtype: object

# %%
df["Airline_"].value_counts()
# Out:
# Vistara       592
# Indigo Air    471
# Air India     282
# Spice Jet     185
# Air Asia      172
# Go Air        125
# Name: Airline_, dtype: int64

# %%
df["Source"].value_counts()
# Out:
# MAA    1827
# Name: Source, dtype: int64

# %%
df["Destination"].value_counts()
# Out:
# DEL    1827
# Name: Destination, dtype: int64

# %%
df["Price"].value_counts()
# Out:
# 7752     263
# 6853      59
# 11848     51
# 5839      38
# 8376      36
#         ...
# 9474       1
# 17675      1
# 9486       1
# 17655      1
# 11729      1
# Name: Price, Length: 506, dtype: int64

# %%
df["date"].value_counts()
# Out:
# 7     310
# 9     288
# 26    262
# 11    160
# 17    154
# 3     151
# 5     145
# 29    130
# 27    120
# 25     77
# 24     30
# Name: date, dtype: int64

# %%
df["month"].value_counts()
# Out:
# nov    1196
# oct     471
# dec     160
# Name: month, dtype: int64

# %%
for i in df.columns:
        print(str(i))
        print(df[i].value_counts())
        print("\n")
# Out:
# Airline_
# Vistara       592
# Indigo Air    471
# Air India     282
# Spice Jet     185
# Air Asia      172
# Go Air        125
# Name: Airline_, dtype: int64
#
#
# Source
# MAA    1827
# Name: Source, dtype: int64
#
#
# Destination
# DEL    1827
# Name: Destination, dtype: int64
#
#
# no_of_stops
# 1Stop      1287
# 2Stop       333
# NonStop     207
# Name: no_of_stops, dtype: int64
#
#
# Price
# 7752     263
# 6853      59
# 11848     51
# 5839      38
# 8376      36
#         ...
# 9474       1
# 17675      1
# 9486       1
# 17655      1
# 11729      1
# Name: Price, Length: 506, dtype: int64
#
#
# date
# 7     310
# 9     288
# 26    262
# 11    160
# 17    154
# 3     151
# 5     145
# 29    130
# 27    120
# 25     77
# 24     30
# Name: date, dtype: int64
#
#
# month
# nov    1196
# oct     471
# dec     160
# Name: month, dtype: int64
#
#
# Duration_hours
# 2     176
# 5     170
# 6     160
# 7     152
# 9     126
# 12     96
# 11     84
# 8      83
# 10     79
# 14     65
# ...

# %%
df.head()
# Out:
#      Airline_ Source Destination no_of_stops  Price date month  \
# 0   Spice Jet    MAA         DEL     NonStop   5858   24   oct
# 1  Indigo Air    MAA         DEL     NonStop   5937   24   oct
# 2   Spice Jet    MAA         DEL       1Stop   6290   24   oct
# 3    Air Asia    MAA         DEL       1Stop   6853   24   oct
# 4     Vistara    MAA         DEL     NonStop   7286   24   oct
#
#    Duration_hours  Duration_mins Departure hour Departure min Arrival hour  \
# 0               2             50             20            00           22
# 1               3             10             21            50           01
# 2               5             30             19            50           01
# 3              15             25             22            40           14
# 4               2             50             21            05           23
#
#   Arrival min
# 0          50
# 1          00
# 2          20
# 3          05
# 4          55

# %%
df["Airline_"].replace({"Vistara":1,"Indigo Air":2,"Air India":3,"Spice Jet":4,"Air Asia":5,"Go Air":6}, inplace = True)

# %%
df["Source"].replace({"MAA":1}, inplace = True)

# %%
df["Destination"].replace({"DEL":1}, inplace = True)

# %%
df["month"].replace({"oct":1,"nov":2,"dec":3}, inplace = True)

# %%
df.head()
# Out:
#    Airline_  Source  Destination no_of_stops  Price date  month  \
# 0         4       1            1     NonStop   5858   24      1
# 1         2       1            1     NonStop   5937   24      1
# 2         4       1            1       1Stop   6290   24      1
# 3         5       1            1       1Stop   6853   24      1
# 4         1       1            1     NonStop   7286   24      1
#
#    Duration_hours  Duration_mins Departure hour Departure min Arrival hour  \
# 0               2             50             20            00           22
# 1               3             10             21            50           01
# 2               5             30             19            50           01
# 3              15             25             22            40           14
# 4               2             50             21            05           23
#
#   Arrival min
# 0          50
# 1          00
# 2          20
# 3          05
# 4          55

# %%
df.dtypes
# Out:
# Airline_           int64
# Source             int64
# Destination        int64
# no_of_stops       object
# Price              int64
# date              object
# month              int64
# Duration_hours     int64
# Duration_mins      int64
# Departure hour    object
# Departure min     object
# Arrival hour      object
# Arrival min       object
# dtype: object

# %%
file_name = 'flig_pred.xlsx'    
df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
ds=pd.read_excel("fli_pred.xls")

# %%
ds
# Out:
#       Unnamed: 0  Airline  Source  Destination no_of_stops  Price  date  \
# 0              0        4       1            1     NonStop   5858    24
# 1              1        2       1            1     NonStop   5937    24
# 2              2        4       1            1       1Stop   6290    24
# 3              3        5       1            1       1Stop   6853    24
# 4              4        1       1            1     NonStop   7286    24
# ...          ...      ...     ...          ...         ...    ...   ...
# 1822        1822        5       1            1       1Stop  10803     7
# 1823        1823        2       1            1     NonStop  11970     7
# 1824        1824        1       1            1       2Stop  17655     7
# 1825        1825        3       1            1       1Stop  21446     7
# 1826        1826        3       1            1       1Stop  21446     7
#
#       month  Duration_hours  Duration_mins  Departure_hour  Departure_min  \
# ...

# %%
ds.dtypes
# Out:
# Unnamed: 0         int64
# Airline            int64
# Source             int64
# Destination        int64
# no_of_stops       object
# Price              int64
# date               int64
# month              int64
# Duration_hours     int64
# Duration_mins      int64
# Departure_hour     int64
# Departure_min      int64
# Arrival_hour       int64
# Arrival_min        int64
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
for i in ds.columns:
    if ds[i].dtypes==object:
        ds[i]=oe.fit_transform(ds[i].values.reshape(-1,1))

# %%
ds.head()
# Out:
#    Unnamed: 0  Airline  Source  Destination  no_of_stops  Price  date  month  \
# 0           0        4       1            1          2.0   5858    24      1
# 1           1        2       1            1          2.0   5937    24      1
# 2           2        4       1            1          0.0   6290    24      1
# 3           3        5       1            1          0.0   6853    24      1
# 4           4        1       1            1          2.0   7286    24      1
#
#    Duration_hours  Duration_mins  Departure_hour  Departure_min  Arrival_hour  \
# 0               2             50              20              0            22
# 1               3             10              21             50             1
# 2               5             30              19             50             1
# 3              15             25              22             40            14
# 4               2             50              21              5            23
#
#    Arrival_min
# 0           50
# ...

# %%
ds=ds.astype(float)

# %%
ds
# Out:
#       Unnamed: 0  Airline  Source  Destination  no_of_stops    Price  date  \
# 0            0.0      4.0     1.0          1.0          2.0   5858.0  24.0
# 1            1.0      2.0     1.0          1.0          2.0   5937.0  24.0
# 2            2.0      4.0     1.0          1.0          0.0   6290.0  24.0
# 3            3.0      5.0     1.0          1.0          0.0   6853.0  24.0
# 4            4.0      1.0     1.0          1.0          2.0   7286.0  24.0
# ...          ...      ...     ...          ...          ...      ...   ...
# 1822      1822.0      5.0     1.0          1.0          0.0  10803.0   7.0
# 1823      1823.0      2.0     1.0          1.0          2.0  11970.0   7.0
# 1824      1824.0      1.0     1.0          1.0          1.0  17655.0   7.0
# 1825      1825.0      3.0     1.0          1.0          0.0  21446.0   7.0
# 1826      1826.0      3.0     1.0          1.0          0.0  21446.0   7.0
#
# ...

# %%
ds.dtypes
# Out:
# Unnamed: 0        float64
# Airline           float64
# Source            float64
# Destination       float64
# no_of_stops       float64
# Price             float64
# date              float64
# month             float64
# Duration_hours    float64
# Duration_mins     float64
# Departure_hour    float64
# Departure_min     float64
# Arrival_hour      float64
# Arrival_min       float64
# dtype: object

# %%
for i in ds.columns:
    print((i))
    print(ds[i].value_counts())
    print("\n")
# Out:
# Unnamed: 0
# 1803.0    1
# 963.0     1
# 1566.0    1
# 1346.0    1
# 827.0     1
#          ..
# 262.0     1
# 788.0     1
# 794.0     1
# 796.0     1
# 0.0       1
# Name: Unnamed: 0, Length: 1827, dtype: int64
#
#
# Airline
# 1.0    592
# 2.0    471
# 3.0    282
# 4.0    185
# 5.0    172
# 6.0    125
# Name: Airline, dtype: int64
#
#
# Source
# 1.0    1827
# Name: Source, dtype: int64
#
#
# Destination
# 1.0    1827
# Name: Destination, dtype: int64
#
#
# no_of_stops
# 0.0    1287
# 1.0     333
# 2.0     207
# Name: no_of_stops, dtype: int64
#
#
# Price
# 7752.0     263
# 6853.0      59
# 11848.0     51
# 5839.0      38
# 8376.0      36
#           ...
# 7297.0       1
# 12371.0      1
# 7532.0       1
# 6254.0       1
# 24448.0      1
# Name: Price, Length: 506, dtype: int64
#
#
# date
# 7.0     310
# 9.0     288
# 26.0    262
# 11.0    160
# 17.0    154
# 3.0     151
# 5.0     145
# 29.0    130
# 27.0    120
# 25.0     77
# 24.0     30
# Name: date, dtype: int64
#
#
# month
# ...

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'Airline', 'Source', 'Destination', 'no_of_stops',
#        'Price', 'date', 'month', 'Duration_hours', 'Duration_mins',
#        'Departure_hour', 'Departure_min', 'Arrival_hour', 'Arrival_min'],
#       dtype='object')

# %%
ds.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for  i in ds[col]:
    
    plt.figure()
    plt.figure(figsize=(15,7))
    plt.xticks(rotation=90)
    sb.countplot(ds[i])

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for  i in ds[col]:
    plt.figure()
    plt.figure(figsize=(15,7))
    sb.violinplot(x=ds[i], y="Price", data=ds, inner=None)

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for i in ds[col]:
    plt.figure()
    sb.swarmplot(x=ds[i],y="Price", data=ds,size=6)

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for i in ds[col]:
    plt.figure()
    plt.figure(figsize=(15,7))
    ax=sb.violinplot(x=ds[i],y="Price",data=ds,inner=None)
    ax=sb.swarmplot(x=ds[i],y="Price",data=ds,color='white',edgecolor="gray")

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for i in ds[col]:
    plt.figure()
    sb.swarmplot(x=ds[i],y="Price",hue="no_of_stops", data=ds,size=6)

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for  i in ds[col]:
    plt.figure()
    sb.catplot(x=ds[i],y="Price",data=ds)

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for  i in ds.columns:
    plt.figure()
    sb.distplot(x=ds[i])

# %%
for  i in ds.columns:
    plt.figure()
    sb.boxplot(x=ds[i])

# %%
for i in ds.columns:
    
    plt.figure()
    plt.figure(figsize=(12,6))
    sb.boxenplot(x=ds[i],y='Price',data=df)

# %%
for i in ds.columns:
    
    plt.figure()
    plt.figure(figsize=(12,6))
    sb.stripplot(x=ds[i],y='Price',data=df)

# %%
for i in ds[col]:
    
    plt.figure()
    plt.figure(figsize=(12,6))
    sb.countplot(x=ds[i],hue="Airline",data=ds)

# %%
col=['Airline', 'Source', 'Destination', 'no_of_stops','date', 'month',]

for  i in ds[col]:
    plt.figure()
    sb.jointplot(x=ds[i],y='Price',data=ds,color='c')

# %%
sb.pairplot(ds)

# %%
ds.describe()
# Out:
#            Airline  Source  Destination  no_of_stops         Price  \
# count  1827.000000  1827.0       1827.0  1827.000000   1827.000000
# mean      2.588944     1.0          1.0     0.408867  10252.259442
# std       1.574770     0.0          0.0     0.684509   4887.886865
# min       1.000000     1.0          1.0     0.000000   2670.000000
# 25%       1.000000     1.0          1.0     0.000000   7331.000000
# 50%       2.000000     1.0          1.0     0.000000   8376.000000
# 75%       4.000000     1.0          1.0     1.000000  12898.000000
# max       6.000000     1.0          1.0     2.000000  72497.000000
#
#               date        month  Duration_hours  Duration_mins  \
# count  1827.000000  1827.000000     1827.000000    1827.000000
# mean     14.660646     1.829776       11.996716      27.859332
# std       9.183823     0.562647        8.293559      18.333034
# min       3.000000     1.000000        2.000000       0.000000
# ...

# %%
plt.figure(figsize=(22,7))
sb.heatmap(ds.describe(),annot=True,linewidths=0.1,linecolor="purple",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sb.heatmap(ds.corr(),annot=True,linewidths=0.1,linecolor="purple",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
ds.corr()["Price"].sort_values(ascending=False).drop(["Price"]).plot(kind="bar",color="c")
plt.xlabel("feature",fontsize=14)
plt.ylabel("column with target name",fontsize=14)
plt.title("correlation",fontsize=22)
plt.show()

# %%
ds.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'no_of_stops', 'Price', 'date',
#        'month', 'Duration_hours', 'Duration_mins', 'Departure_hour',
#        'Departure_min', 'Arrival_hour', 'Arrival_min'],
#       dtype='object')

# %%
airline= pd.get_dummies(ds, columns = ['Airline',"month"])
print(airline)
# Out:
#       Source  Destination  no_of_stops    Price  date  Duration_hours  \
# 0        1.0          1.0          2.0   5858.0  24.0             2.0
# 1        1.0          1.0          2.0   5937.0  24.0             3.0
# 2        1.0          1.0          0.0   6290.0  24.0             5.0
# 3        1.0          1.0          0.0   6853.0  24.0            15.0
# 4        1.0          1.0          2.0   7286.0  24.0             2.0
# ...      ...          ...          ...      ...   ...             ...
# 1822     1.0          1.0          0.0  10803.0   7.0            17.0
# 1823     1.0          1.0          2.0  11970.0   7.0             3.0
# 1824     1.0          1.0          1.0  17655.0   7.0            10.0
# 1825     1.0          1.0          0.0  21446.0   7.0             8.0
# 1826     1.0          1.0          0.0  21446.0   7.0            29.0
#
#       Duration_mins  Departure_hour  Departure_min  Arrival_hour  Arrival_min  \
# ...

# %%
ds=pd.DataFrame(airline)

# %%
ds
# Out:
#       Source  Destination  no_of_stops    Price  date  Duration_hours  \
# 0        1.0          1.0          2.0   5858.0  24.0             2.0
# 1        1.0          1.0          2.0   5937.0  24.0             3.0
# 2        1.0          1.0          0.0   6290.0  24.0             5.0
# 3        1.0          1.0          0.0   6853.0  24.0            15.0
# 4        1.0          1.0          2.0   7286.0  24.0             2.0
# ...      ...          ...          ...      ...   ...             ...
# 1822     1.0          1.0          0.0  10803.0   7.0            17.0
# 1823     1.0          1.0          2.0  11970.0   7.0             3.0
# 1824     1.0          1.0          1.0  17655.0   7.0            10.0
# 1825     1.0          1.0          0.0  21446.0   7.0             8.0
# 1826     1.0          1.0          0.0  21446.0   7.0            29.0
#
#       Duration_mins  Departure_hour  Departure_min  Arrival_hour  Arrival_min  \
# ...

# %%
ds.drop(["Source","Destination"],axis=1,inplace=True)

# %%
ds[(ds["Price"]>70000)]
# Out:
#      no_of_stops    Price  date  Duration_hours  Duration_mins  \
# 751          0.0  72497.0   3.0             8.0           50.0
#
#      Departure_hour  Departure_min  Arrival_hour  Arrival_min  Airline_1.0  \
# 751             5.0           55.0          14.0         45.0            0
#
#      Airline_2.0  Airline_3.0  Airline_4.0  Airline_5.0  Airline_6.0  \
# 751            0            1            0            0            0
#
#      month_1.0  month_2.0  month_3.0
# 751          0          1          0

# %%
ds.drop(751,inplace=True)

# %%
ds
# Out:
#       no_of_stops    Price  date  Duration_hours  Duration_mins  \
# 0             2.0   5858.0  24.0             2.0           50.0
# 1             2.0   5937.0  24.0             3.0           10.0
# 2             0.0   6290.0  24.0             5.0           30.0
# 3             0.0   6853.0  24.0            15.0           25.0
# 4             2.0   7286.0  24.0             2.0           50.0
# ...           ...      ...   ...             ...            ...
# 1822          0.0  10803.0   7.0            17.0           50.0
# 1823          2.0  11970.0   7.0             3.0            0.0
# 1824          1.0  17655.0   7.0            10.0            5.0
# 1825          0.0  21446.0   7.0             8.0           50.0
# 1826          0.0  21446.0   7.0            29.0           10.0
#
#       Departure_hour  Departure_min  Arrival_hour  Arrival_min  Airline_1.0  \
# 0               20.0            0.0          22.0         50.0            0
# ...

# %%
x=ds.drop("Price",axis=1)
y=ds["Price"]

# %%
x
# Out:
#       no_of_stops  date  Duration_hours  Duration_mins  Departure_hour  \
# 0             2.0  24.0             2.0           50.0            20.0
# 1             2.0  24.0             3.0           10.0            21.0
# 2             0.0  24.0             5.0           30.0            19.0
# 3             0.0  24.0            15.0           25.0            22.0
# 4             2.0  24.0             2.0           50.0            21.0
# ...           ...   ...             ...            ...             ...
# 1822          0.0   7.0            17.0           50.0            18.0
# 1823          2.0   7.0             3.0            0.0            12.0
# 1824          1.0   7.0            10.0            5.0             7.0
# 1825          0.0   7.0             8.0           50.0             5.0
# 1826          0.0   7.0            29.0           10.0             9.0
#
#       Departure_min  Arrival_hour  Arrival_min  Airline_1.0  Airline_2.0  \
# ...

# %%
s.astype()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-2bec7d84dda1> in <module>
# ----> 1 s.astype()
#
# NameError: name 's' is not defined

# %%
y

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error,mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

# %%
lr=LinearRegression()
rfr=RandomForestRegressor()
dtr=DecisionTreeRegressor()
knr=KNeighborsRegressor()
svr=SVR()

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
        rfr.fit(x_train,y_train)
        pred=rfr.predict(x_test)
        acc=r2_score(y_test,pred)
        if acc>maxAccu:
            maxAccu=acc
            maxRS=i
print("Best R2 Score ",maxAccu,"On Random State", maxRS)

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
        dtr.fit(x_train,y_train)
        pred=dtr.predict(x_test)
        acc=r2_score(y_test,pred)
        if acc>maxAccu:
            maxAccu=acc
            maxRS=i
print("Best R2 Score ",maxAccu,"On Random State", maxRS)

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
        lr.fit(x_train,y_train)
        pred=lr.predict(x_test)
        acc=r2_score(y_test,pred)
        if acc>maxAccu:
            maxAccu=acc
            maxRS=i
print("Best accuracy is",maxAccu,"On Random State", maxRS)

# %%
parameters={"criterion":["mse","mae"],"max_features":["auto","sqrt","log2"]}
rfr=RandomForestRegressor()
clf=GridSearchCV(rfr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

# %%
rfr=RandomForestRegressor(criterion="mse",max_features="auto")
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=175)
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
pred_rfr=rfr.predict(x_test)

rfs=r2_score(y_test,pred_rfr)
print("R2 Score",rfs*100)
# Out:
# R2 Score 82.3921804917076

# %%
print("error =Random Forest Regressor:")

print("mean absolute error:",mean_absolute_error(y_test,pred_rfr))
print("mean squared error:",mean_squared_error(y_test,pred_rfr))

print("root mean squared error:",np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
# error =Random Forest Regressor:
# mean absolute error: 1198.5641913869374
# mean squared error: 4275643.977315639
# root mean squared error: 2067.763037031961

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_decision,color="r")
plt.plot(y_test,y_test,color="b")
plt.xlabel("Actual Price",fontsize=14)
plt.ylabel("predicted Price", fontsize=14)
plt.title("Random Forest Regressor",fontsize=18)
plt.show()

# %%
sb.distplot(y_test-pred_rfr)
plt.show()

# %%
plt.scatter(y_test, pred_rfr, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
import pickle
filename="flight_pred.pkl"
pickle.dump(rfr,open(filename,"wb"))

# %%
loaded_model=pickle.load(open('flight_pred.pkl',"rb"))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8239218049170761

# %%
Conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","Original"])
Conclusion
# Out:
#                0        1        2        3         4         5         6    \
# predicted  6735.49  8265.81  6852.81  5278.43  10727.87  11018.33  15520.63
# Original   6718.31  8299.74  6899.52  5389.99  10457.12  11183.68  15599.73
#
#                7        8        9    ...      356       357      358  \
# predicted  4875.12  7832.47  6376.79  ...  7759.77  16249.78  8650.81
# Original   4915.49  7802.32  6217.44  ...  7779.11  15490.64  8325.21
#
#                359      360          361       362       363      364  \
# predicted  5665.26  5751.50  8114.603500  10399.92  35118.56  5204.68
# Original   5772.73  5608.14  8444.484167  10525.32  35992.02  4904.07
#
#                     365
# predicted  14111.670167
# Original   13853.724333
#
# [2 rows x 366 columns]

# %%
ds.head()
# Out:
#    no_of_stops  Price  date  Duration_hours  Duration_mins  Departure_hour  \
# 0          2.0   5858    24               2             50              20
# 1          2.0   5937    24               3             10              21
# 2          0.0   6290    24               5             30              19
# 3          0.0   6853    24              15             25              22
# 4          2.0   7286    24               2             50              21
#
#    Departure_min  Arrival_hour  Arrival_min  Airline_1  Airline_2  Airline_3  \
# 0              0            22           50          0          0          0
# 1             50             1            0          0          1          0
# 2             50             1           20          0          0          0
# 3             40            14            5          0          0          0
# 4              5            23           55          1          0          0
#
# ...

# %%
Future_pred=[[2.0,24,2,50,20,0,22,50,0,0,0,1,0,0,1,0,0]]
pred= rfr.predict(Future_pred)
print(pred)
# Out:
# [6554.07]
